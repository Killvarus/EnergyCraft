# %% [markdown]
# # MLP Mosaic Pipeline (non-overlap windows)
#
# Этот ноутбук запускает отдельный pipeline:
# 1) читает shot gathers и модель скорости,
# 2) приводит координаты к системе модели,
# 3) отрезает перекрытия между shot,
# 4) собирает единую мозаику,
# 5) режет на окна, split 70/20/10,
# 6) обучает MLP и сохраняет summary.

# %%
import sys
from pathlib import Path

project_root = Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print('project_root =', project_root)

# %%
from run_mlp_mosaic import run_mlp_mosaic

run_mlp_mosaic()

# %%
import json
from pathlib import Path

summary_path = Path('outputs/summary_mlp_mosaic.json')
with open(summary_path, 'r', encoding='utf-8') as f:
    summary = json.load(f)

summary
